# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gmaps
import gmaps.datasets
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

gmaps.configure(api_key='AI...')

# %%
#Load Data
df = pd.read_csv('lat_lon_full.csv')
df = df[['lat_four', 'lng_four', 'city', 'town', 'village', 'hamlet', 'state_district']]

# %% [markdown]
# # Viewing Distribution of Trips

# %%
lat_lon = list(zip(df['lat_four'], df['lng_four']))
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(lat_lon))
fig
# Out:
# A Jupyter Widget

# %% [markdown]
# # Image
# ### Github doesn't support activating Javascript within a workbook - had to do this a quick work around.

# %% [markdown]
# <img src="img/DataCubed-Map.png">

# %% [markdown]
# # Location Type
# The majority of the dataset is made up of cities.

# %%
loc_counts = df[['city','town','village','hamlet']].count()
sns.barplot(loc_counts.index, loc_counts.values, color="#0075b2")
plt.show()

loc_counts.index
# Out:
# Index(['city', 'town', 'village', 'hamlet'], dtype='object')

# %% [markdown]
# # Breakdown by district

# %%
most_popular_district = df['state_district'].value_counts()
sns.barplot(x=most_popular_district.head(10).values, y=most_popular_district.head(10).index, color="#0075b2")
plt.title("Most Common Districts")
plt.show()

# %% [markdown]
# # Most Popular Cities

# %%
most_popular_cities = df['city'].value_counts()
sns.barplot(x=most_popular_cities.head(10).values, y=most_popular_cities.head(10).index, color="#0075b2")
plt.title("Most Common Cities")
plt.show()

# %% [markdown]
# # Most Common towns

# %%
most_popular_towns = df['town'].value_counts()
sns.barplot(x=most_popular_towns.head(10).values, y=most_popular_towns.head(10).index, color="#0075b2")
plt.title("Towns included in dataset")
plt.show()
